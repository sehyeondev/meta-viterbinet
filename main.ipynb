# %%
from python_code.trainers.VA.va_trainer import VATrainer

# %%
dec = VATrainer()

# %%
ser = dec.evaluate()
# Out:
# Starts evaluation at gamma 0.2
# Done. time: 1.6011602878570557, ser: [2.26319432e-01 2.07291663e-01 1.83958292e-01 1.56666636e-01
#  1.32361114e-01 1.01249993e-01 7.91666508e-02 5.49999475e-02
#  3.62499952e-02 2.01388597e-02 1.40277743e-02 7.98606873e-03
#  4.86075878e-04 8.33332539e-04 0.00000000e+00 0.00000000e+00
#  1.38878822e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00]

# %%
dec.detector
# Out:
# VADetector()

# %%
import matplotlib.pyplot as plt
import numpy as np

val_SNR_start = 0
val_SNR_end = 20
val_SNR_step = 1
snr_range = np.arange(val_SNR_start, val_SNR_end + 1, step=val_SNR_step)

plt.plot(snr_range, ser)
plt.xlabel('SNR')
plt.ylabel('SER')
plt.title('Viterbi Algorithm')
plt.grid()
plt.show()
